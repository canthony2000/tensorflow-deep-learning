# %% [markdown]
# # Crash Course Review Exercises - Corey Anthony 10/4/2019

# %% [markdown]
# ** Import numpy,pandas,matplotlib,and sklearn. Also set visualizations to be shown inline in the notebook.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ** Set Numpy's Random Seed to 101 **

# %%
np.random.seed(101)

# %% [markdown]
# ** Create a NumPy Matrix of 100 rows by 5 columns consisting of random integers from 1-100. (Keep in mind that the upper limit may be exclusive.**

# %%
mat = np.random.randint(1,101,(100,5))

# %%
mat
# Out:
# array([[ 15,  61,  66,  19,  94],
#        [ 13,  79,  48,  73,  97],
#        [ 67,  94,  56,  25,  64],
#        [ 33,  64,   7,  95,  17],
#        [ 35,  48,   2,  17,  46],
#        [ 12,  52,  65,   5,  49],
#        [ 81,  98,  27,  49,   3],
#        [ 92,   1,  11,  74,  11],
#        [ 32,  85,  91,  42,  98],
#        [ 72,  61,  86,  97,  50],
#        [ 75,  57,  74,  47,  67],
#        [ 46,  28,  97,  83,  17],
#        [ 82,  26,   8,  64,   7],
#        [ 20,  94,  18,  79,  84],
#        [ 84,  15,  44,  18,  11],
#        [ 21,  30,  15,  47,  13],
#        [  2, 100,  28,  27,  25],
#        [100,  27,  43,  21,  22],
#        [ 75,  15,  36,  52,  63],
#        [ 46,  18,  91,  15,   7],
#        [ 14,  42,  90,  82,   3],
#        [ 76,  59,  60,  67,  85],
#        [ 58,  88,  87,  43,  37],
#        [ 87,  81,  85,   1,  26],
#        [ 65,  72,  48,  38,  59],
#        [ 94,  23,  69,  41,  35],
#        [ 46,  45,  75,   5,  67],
#        [ 87,  41,  25,  70,  33],
#        [ 24,   7,  58,   9,   1],
#        [ 43,  75,  33,   3,  56],
#        [ 65,  63,  86,  33,  14],
#        [ 58,  28,  31,  64,  92],
#        [ 67,  73,   4,  18,  41],
#        [ 34,  42,   6,  44,  62],
#        [ 55,  14,  54,  11,  80],
#        [  2,  51,  25,   4,  13],
#        [ 62,  39,   9,   5,  11],
#        [ 77,  92,  22,  33,  13],
#        [ 81,  47,  67,  96,  86],
#        [ 14,  50,  79,  66,  89],
#        [ 42,  74,  73,  82, 100],
#        [ 24,  37,  82,  52,  88],
#        [ 57,  39,  90,  31,  81],
#        [ 95,  15,  68,  67,  36],
#        [ 44,  47,   9,  94,  58],
#        [ 43,  49,  35,  42, 100],
#        [ 26,   5,  92,  19,  93],
#        [ 62,  13,  22,  29,  51],
#        [ 69,  55,   6,  30,  62],
#        [ 50,  35,  53,  51,  34],
#        [ 76,  98, 100,  79,  75],
#        [ 52,  98,  64,  37,  51],
#        [ 58,  35,  95,   1,  86],
#        [ 85,  91,  65,   5,  98],
#        [ 28,  47,  59,   5,  33],
#        [ 11,  59,  79,   7,   5],
#        [  8,  74,  25,  91,  37],
#        [ 14,  95,  24,  49,  19],
#        [ 97,  79,  49,  53,  30],
#        [ 28,  57,  97,  44,  93],
#        [ 85,  26,  20,  89,  68],
#        [ 25,  47,  71,  65,  31],
#        [ 10,  60,  59,  47,  25],
#        [ 48,  72,  24,  17,  13],
#        [  6,  26,  52,  32,  10],
#        [ 79,  92,  10,  24,  23],
#        [100,  21,  12,  52,  11],
#        [ 80,   9,  52,  44,  94],
#        [ 53,  33,  69,   4,  90],
#        [  6,  98,  61,  22,  51],
#        [ 49,  51,  73,  99,  90],
#        [ 90,  91,  29,  50,  36],
#        [ 79,  10,  46,  76,  19],
#        [  4,  34,  78,  41,   7],
#        [ 42,  73,  88,  92,  63],
#        [ 24,  29,  73,  64,  94],
#        [ 51,  47,  59,  60,  67],
#        [ 90,  55,  72,  94,  37],
#        [  5,  91,  19,   7,   3],
#        [ 70,  12,  68,  58,  13],
#        [  2,  48,  32,  38,  90],
#        [ 20,  56,  26,  13,  76],
#        [ 31,  60,  74,  96,  22],
#        [ 32,  19,  48,  90, 100],
#        [ 81,  82,  88,  62,  62],
#        [ 40,  81,  70,  73,  31],
#        [ 64,  56,  48,   1,  12],
#        [ 72,  62,  96,  69,  39],
#        [ 95,  18,  73,  96,  68],
#        [ 96,  62,  55,  53,  14],
#        [ 30,  82,   1,   6,  57],
#        [ 84,  82,  57,  50,  57],
#        [ 93,  53,  12,  18,  49],
#        [ 42,  66,  64,  79,  30],
#        [ 98,  24,  81,   5,  69],
#        [ 73,   3,   4,  21,  85],
#        [ 92,  91,  69,  95,  51],
#        [ 89,  68,  80,  53,  93],
#        [ 24,  62,  72,   3,  31],
#        [  5,  86,  72,   7,  56]])

# %% [markdown]
# ** Create a 2-D visualization using plt.imshow of the numpy matrix with a colorbar. Add a title to your plot. Bonus: Figure out how to change the [*aspect*](https://stackoverflow.com/questions/10540929/figure-of-imshow-is-too-small) of the imshow() plot. **

# %%
plt.imshow(mat,aspect=0.05)
plt.colorbar()
plt.title('My Plot')
# Out:
# Text(0.5, 1.0, 'My Plot')

# %% [markdown]
# ** Now use pd.DataFrame() to read in this numpy array as a dataframe. Simple pass in the numpy array into that function to get back a dataframe. Pandas will auto label the columns to 0-4**

# %%
df = pd.DataFrame(mat)

# %%
df
# Out:
#       0    1   2   3    4
# 0    15   61  66  19   94
# 1    13   79  48  73   97
# 2    67   94  56  25   64
# 3    33   64   7  95   17
# 4    35   48   2  17   46
# 5    12   52  65   5   49
# 6    81   98  27  49    3
# 7    92    1  11  74   11
# 8    32   85  91  42   98
# 9    72   61  86  97   50
# 10   75   57  74  47   67
# 11   46   28  97  83   17
# 12   82   26   8  64    7
# 13   20   94  18  79   84
# 14   84   15  44  18   11
# 15   21   30  15  47   13
# 16    2  100  28  27   25
# 17  100   27  43  21   22
# 18   75   15  36  52   63
# 19   46   18  91  15    7
# 20   14   42  90  82    3
# 21   76   59  60  67   85
# 22   58   88  87  43   37
# 23   87   81  85   1   26
# 24   65   72  48  38   59
# 25   94   23  69  41   35
# 26   46   45  75   5   67
# 27   87   41  25  70   33
# 28   24    7  58   9    1
# 29   43   75  33   3   56
# ..  ...  ...  ..  ..  ...
# 70   49   51  73  99   90
# 71   90   91  29  50   36
# 72   79   10  46  76   19
# 73    4   34  78  41    7
# 74   42   73  88  92   63
# 75   24   29  73  64   94
# 76   51   47  59  60   67
# 77   90   55  72  94   37
# 78    5   91  19   7    3
# 79   70   12  68  58   13
# 80    2   48  32  38   90
# 81   20   56  26  13   76
# 82   31   60  74  96   22
# 83   32   19  48  90  100
# 84   81   82  88  62   62
# 85   40   81  70  73   31
# 86   64   56  48   1   12
# 87   72   62  96  69   39
# 88   95   18  73  96   68
# 89   96   62  55  53   14
# 90   30   82   1   6   57
# 91   84   82  57  50   57
# 92   93   53  12  18   49
# 93   42   66  64  79   30
# 94   98   24  81   5   69
# 95   73    3   4  21   85
# 96   92   91  69  95   51
# 97   89   68  80  53   93
# 98   24   62  72   3   31
# 99    5   86  72   7   56
#
# [100 rows x 5 columns]

# %% [markdown]
# ** Now create a scatter plot using pandas of the 0 column vs the 1 column. **

# %%
df.plot(x=0,y=1,kind='scatter')

# %% [markdown]
# ** Now scale the data to have a minimum of 0 and a maximum value of 1 using scikit-learn. **

# %%
scaler_model = MinMaxScaler()

# %%
scaler_model.fit_transform(mat)
# Out:
# //anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[0.13265306, 0.60606061, 0.65656566, 0.18367347, 0.93939394],
#        [0.1122449 , 0.78787879, 0.47474747, 0.73469388, 0.96969697],
#        [0.66326531, 0.93939394, 0.55555556, 0.24489796, 0.63636364],
#        [0.31632653, 0.63636364, 0.06060606, 0.95918367, 0.16161616],
#        [0.33673469, 0.47474747, 0.01010101, 0.16326531, 0.45454545],
#        [0.10204082, 0.51515152, 0.64646465, 0.04081633, 0.48484848],
#        [0.80612245, 0.97979798, 0.26262626, 0.48979592, 0.02020202],
#        [0.91836735, 0.        , 0.1010101 , 0.74489796, 0.1010101 ],
#        [0.30612245, 0.84848485, 0.90909091, 0.41836735, 0.97979798],
#        [0.71428571, 0.60606061, 0.85858586, 0.97959184, 0.49494949],
#        [0.74489796, 0.56565657, 0.73737374, 0.46938776, 0.66666667],
#        [0.44897959, 0.27272727, 0.96969697, 0.83673469, 0.16161616],
#        [0.81632653, 0.25252525, 0.07070707, 0.64285714, 0.06060606],
#        [0.18367347, 0.93939394, 0.17171717, 0.79591837, 0.83838384],
#        [0.83673469, 0.14141414, 0.43434343, 0.17346939, 0.1010101 ],
#        [0.19387755, 0.29292929, 0.14141414, 0.46938776, 0.12121212],
#        [0.        , 1.        , 0.27272727, 0.26530612, 0.24242424],
#        [1.        , 0.26262626, 0.42424242, 0.20408163, 0.21212121],
#        [0.74489796, 0.14141414, 0.35353535, 0.52040816, 0.62626263],
#        [0.44897959, 0.17171717, 0.90909091, 0.14285714, 0.06060606],
#        [0.12244898, 0.41414141, 0.8989899 , 0.82653061, 0.02020202],
#        [0.75510204, 0.58585859, 0.5959596 , 0.67346939, 0.84848485],
#        [0.57142857, 0.87878788, 0.86868687, 0.42857143, 0.36363636],
#        [0.86734694, 0.80808081, 0.84848485, 0.        , 0.25252525],
#        [0.64285714, 0.71717172, 0.47474747, 0.37755102, 0.58585859],
#        [0.93877551, 0.22222222, 0.68686869, 0.40816327, 0.34343434],
#        [0.44897959, 0.44444444, 0.74747475, 0.04081633, 0.66666667],
#        [0.86734694, 0.4040404 , 0.24242424, 0.70408163, 0.32323232],
#        [0.2244898 , 0.06060606, 0.57575758, 0.08163265, 0.        ],
#        [0.41836735, 0.74747475, 0.32323232, 0.02040816, 0.55555556],
#        [0.64285714, 0.62626263, 0.85858586, 0.32653061, 0.13131313],
#        [0.57142857, 0.27272727, 0.3030303 , 0.64285714, 0.91919192],
#        [0.66326531, 0.72727273, 0.03030303, 0.17346939, 0.4040404 ],
#        [0.32653061, 0.41414141, 0.05050505, 0.43877551, 0.61616162],
#        [0.54081633, 0.13131313, 0.53535354, 0.10204082, 0.7979798 ],
#        [0.        , 0.50505051, 0.24242424, 0.03061224, 0.12121212],
#        [0.6122449 , 0.38383838, 0.08080808, 0.04081633, 0.1010101 ],
#        [0.76530612, 0.91919192, 0.21212121, 0.32653061, 0.12121212],
#        [0.80612245, 0.46464646, 0.66666667, 0.96938776, 0.85858586],
#        [0.12244898, 0.49494949, 0.78787879, 0.66326531, 0.88888889],
#        [0.40816327, 0.73737374, 0.72727273, 0.82653061, 1.        ],
#        [0.2244898 , 0.36363636, 0.81818182, 0.52040816, 0.87878788],
#        [0.56122449, 0.38383838, 0.8989899 , 0.30612245, 0.80808081],
#        [0.94897959, 0.14141414, 0.67676768, 0.67346939, 0.35353535],
#        [0.42857143, 0.46464646, 0.08080808, 0.94897959, 0.57575758],
#        [0.41836735, 0.48484848, 0.34343434, 0.41836735, 1.        ],
#        [0.24489796, 0.04040404, 0.91919192, 0.18367347, 0.92929293],
#        [0.6122449 , 0.12121212, 0.21212121, 0.28571429, 0.50505051],
#        [0.68367347, 0.54545455, 0.05050505, 0.29591837, 0.61616162],
#        [0.48979592, 0.34343434, 0.52525253, 0.51020408, 0.33333333],
#        [0.75510204, 0.97979798, 1.        , 0.79591837, 0.74747475],
#        [0.51020408, 0.97979798, 0.63636364, 0.36734694, 0.50505051],
#        [0.57142857, 0.34343434, 0.94949495, 0.        , 0.85858586],
#        [0.84693878, 0.90909091, 0.64646465, 0.04081633, 0.97979798],
#        [0.26530612, 0.46464646, 0.58585859, 0.04081633, 0.32323232],
#        [0.09183673, 0.58585859, 0.78787879, 0.06122449, 0.04040404],
#        [0.06122449, 0.73737374, 0.24242424, 0.91836735, 0.36363636],
#        [0.12244898, 0.94949495, 0.23232323, 0.48979592, 0.18181818],
#        [0.96938776, 0.78787879, 0.48484848, 0.53061224, 0.29292929],
#        [0.26530612, 0.56565657, 0.96969697, 0.43877551, 0.92929293],
#        [0.84693878, 0.25252525, 0.19191919, 0.89795918, 0.67676768],
#        [0.23469388, 0.46464646, 0.70707071, 0.65306122, 0.3030303 ],
#        [0.08163265, 0.5959596 , 0.58585859, 0.46938776, 0.24242424],
#        [0.46938776, 0.71717172, 0.23232323, 0.16326531, 0.12121212],
#        [0.04081633, 0.25252525, 0.51515152, 0.31632653, 0.09090909],
#        [0.78571429, 0.91919192, 0.09090909, 0.23469388, 0.22222222],
#        [1.        , 0.2020202 , 0.11111111, 0.52040816, 0.1010101 ],
#        [0.79591837, 0.08080808, 0.51515152, 0.43877551, 0.93939394],
#        [0.52040816, 0.32323232, 0.68686869, 0.03061224, 0.8989899 ],
#        [0.04081633, 0.97979798, 0.60606061, 0.21428571, 0.50505051],
#        [0.47959184, 0.50505051, 0.72727273, 1.        , 0.8989899 ],
#        [0.89795918, 0.90909091, 0.28282828, 0.5       , 0.35353535],
#        [0.78571429, 0.09090909, 0.45454545, 0.76530612, 0.18181818],
#        [0.02040816, 0.33333333, 0.77777778, 0.40816327, 0.06060606],
#        [0.40816327, 0.72727273, 0.87878788, 0.92857143, 0.62626263],
#        [0.2244898 , 0.28282828, 0.72727273, 0.64285714, 0.93939394],
#        [0.5       , 0.46464646, 0.58585859, 0.60204082, 0.66666667],
#        [0.89795918, 0.54545455, 0.71717172, 0.94897959, 0.36363636],
#        [0.03061224, 0.90909091, 0.18181818, 0.06122449, 0.02020202],
#        [0.69387755, 0.11111111, 0.67676768, 0.58163265, 0.12121212],
#        [0.        , 0.47474747, 0.31313131, 0.37755102, 0.8989899 ],
#        [0.18367347, 0.55555556, 0.25252525, 0.12244898, 0.75757576],
#        [0.29591837, 0.5959596 , 0.73737374, 0.96938776, 0.21212121],
#        [0.30612245, 0.18181818, 0.47474747, 0.90816327, 1.        ],
#        [0.80612245, 0.81818182, 0.87878788, 0.62244898, 0.61616162],
#        [0.3877551 , 0.80808081, 0.6969697 , 0.73469388, 0.3030303 ],
#        [0.63265306, 0.55555556, 0.47474747, 0.        , 0.11111111],
#        [0.71428571, 0.61616162, 0.95959596, 0.69387755, 0.38383838],
#        [0.94897959, 0.17171717, 0.72727273, 0.96938776, 0.67676768],
#        [0.95918367, 0.61616162, 0.54545455, 0.53061224, 0.13131313],
#        [0.28571429, 0.81818182, 0.        , 0.05102041, 0.56565657],
#        [0.83673469, 0.81818182, 0.56565657, 0.5       , 0.56565657],
#        [0.92857143, 0.52525253, 0.11111111, 0.17346939, 0.48484848],
#        [0.40816327, 0.65656566, 0.63636364, 0.79591837, 0.29292929],
#        [0.97959184, 0.23232323, 0.80808081, 0.04081633, 0.68686869],
#        [0.7244898 , 0.02020202, 0.03030303, 0.20408163, 0.84848485],
#        [0.91836735, 0.90909091, 0.68686869, 0.95918367, 0.50505051],
#        [0.8877551 , 0.67676768, 0.7979798 , 0.53061224, 0.92929293],
#        [0.2244898 , 0.61616162, 0.71717172, 0.02040816, 0.3030303 ],
#        [0.03061224, 0.85858586, 0.71717172, 0.06122449, 0.55555556]])

# %% [markdown]
# ** Using your previously created DataFrame, use [df.columns = [...]](https://stackoverflow.com/questions/11346283/renaming-columns-in-pandas) to rename the pandas columns to be ['f1','f2','f3','f4','label']. Then perform a train/test split with scikitlearn.**

# %%
df.columns=['f1','f2','f3','f4','label']

# %%
df.head()
# Out:
#    f1  f2  f3  f4  label
# 0  15  61  66  19     94
# 1  13  79  48  73     97
# 2  67  94  56  25     64
# 3  33  64   7  95     17
# 4  35  48   2  17     46

# %%
X = df[['f1','f2','f3']]

# %%
y = df['label']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (67, 3)

# %%
X_test.shape
# Out:
# (33, 3)

# %% [markdown]
# # Great Job!
